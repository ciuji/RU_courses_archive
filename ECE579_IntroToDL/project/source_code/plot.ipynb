# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
loss_mat=np.array([
    [ 0.1599 , 0.0936 , 0.0788 , 0.0580 , 0.0492],
    [0.17,0.1020,0.0823,0.0616,0.0518],
    [0.1859,0.1107,0.0872,0.0644,0.0540],
    [0.2037 , 0.1164 , 0.0913 , 0.0667 , 0.0566],
    [0.2141 , 0.1283 , 0.0994 , 0.0767 , 0.0617],
    [0.2410 , 0.1401 , 0.1066 , 0.0845 , 0.0670],
    [0.2792 , 0.1677 , 0.1252 , 0.0988 , 0.0796],
    [0.3395 , 0.2114 , 0.1561 , 0.1211 , 0.1026],
    [1.1630 , 0.3111 , 0.2224 , 0.1696 , 0.1416],
    [2.2903 , 2.2275 , 0.6529 , 0.3787 , 0.3008]
])

# %%
loss_mat=np.array([
    [0.3288 , 0.1772 , 0.1140 , 0.0891 , 0.0750],
    [0.3541,0.1955,0.1177,0.0920,0.0785],
    [0.3747,0.2151,0.1239,0.0962,0.0800],
    [0.3985 , 0.2275 , 0.1372 , 0.1083 , 0.0942],
    [0.5128 , 0.2674 , 0.1567 , 0.1268 , 0.1082],
    [0.6945 , 0.2943 , 0.1818 , 0.1398 , 0.1195],
    [1.8567 , 0.3490 , 0.2286 , 0.1854 , 0.1391],
    [2.2553 , 0.5178 , 0.3055 , 0.2325 , 0.1801],
    [2.2959 , 2.2740 , 1.6289 , 0.4257 , 0.3094],
    [2.3017 , 2.3010 , 2.3008 , 2.3008 , 2.3007]
])

# %%
fig,ax=plt.subplots(figsize=(14,7))
my_colors = [(x/50.0, x/10.0, 0.15) for x in range(10)] 
for i,one in enumerate(loss_mat):
    ax.plot(range(1,6,1),one,marker='*',label=i/10,c=my_colors[i],figure=fig)
#ax.xlim(1,5,1)

ax.set_xticks((range(1,6)))
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)

plt.xlabel('Epoch',fontsize=25)
plt.ylabel('Loss',fontsize=25)
plt.legend(prop={'size': 20})
plt.savefig('loss_resut.pdf', bbox_inches = 'tight')

# %%
fig,ax=plt.subplots(figsize=(14,7))
plt.plot([i/10 for i in range(10)],[9781,9764,9764,9716,9680,9650,9604,9463,9071,1135],marker='D')

ax.set_xticks([i/10 for i in range(10)])
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20)

plt.xlabel('Remove Ratio',fontsize=25)
plt.ylabel('# of Correct Classification',fontsize=25)
plt.savefig('number_5_epoch.pdf', bbox_inches = 'tight')

# %%
large_ratio_list=[[0.2792 , 0.1677 , 0.1252 , 0.0988 , 0.0796,0.0712 ,0.0694, 0.0629, 0.0550, 0.0544],
                  [0.3395,0.2114,0.1562,0.1212,0.1026,0.0873,0.0849,0.0777,0.0638,0.0629 ],
                  [1.16 ,0.3111, 0.2224 ,0.1696,0.1418,0.1164,0.1136,0.0925, 0.0768,0.0769],
                  [2.2903,2.2275,0.6529,0.3786,0.3008,0.2398,0.2164,0.1838,0.1508,0.1382]
                 ]
fig,ax=plt.subplots(figsize=(14,7))
i_list=[0.6,0.7,0.8,0.9]
my_colors = [(x/50.0, x/10.0, 0.15) for x in range(5)] 
for i,one in enumerate(large_ratio_list):
    ax.plot(range(1,11,1),one,marker='*',label=i_list[i],c=my_colors[i],figure=fig)
#ax.xlim(1,5,1)

ax.set_xticks((range(1,11)))
ax.xaxis.set_tick_params(labelsize=20)
ax.yaxis.set_tick_params(labelsize=20
#   0.04372455673217773,
#   0.04090457096099853,
#   0.35412903747558594,
#   0.1955664810180664,
#   0.11805644912719726,
#   0.09225415954589844,
#   0.07868482780456543,
#   0.08560715942382813,
#   0.07052121200561523,
#   0.05826909637451172,
#   0.06682953872680664,
#   0.05593099403381348,
#   0.05160446281433106,
#   0.05184204368591309,
#   0.052435080718994144,
#   0.046643798446655275,
#   0.05102639198303223,
#   0.043457487678527834,
#   0.05089733963012695,
#   0.057017773818969726,
#   0.04687673721313477,
# ...

# %%
len(result)
# Out:
# 10

# %%
result=np.array(result)

# %%
result=result.reshape((-1,20))

# %%
result
# Out:
# array([[0.32927549, 0.17797191, 0.11269099, 0.08920293, 0.07412594,
#         0.08049213, 0.06649345, 0.05737842, 0.06472279, 0.0535806 ,
#         0.0500712 , 0.04964879, 0.05051984, 0.04576469, 0.04809253,
#         0.04300472, 0.05804805, 0.05575107, 0.04372456, 0.04090457],
#        [0.35412904, 0.19556648, 0.11805645, 0.09225416, 0.07868483,
#         0.08560716, 0.07052121, 0.0582691 , 0.06682954, 0.05593099,
#         0.05160446, 0.05184204, 0.05243508, 0.0466438 , 0.05102639,
#         0.04345749, 0.05089734, 0.05701777, 0.04687674, 0.04183837],
#        [0.37465844, 0.21576864, 0.12487433, 0.0962491 , 0.07940348,
#         0.0806444 , 0.07672362, 0.06055068, 0.0678154 , 0.05997254,
#         0.05206908, 0.04949942, 0.05108239, 0.0470027 , 0.05137551,
#         0.04315694, 0.0495929 , 0.05656271, 0.04101905, 0.04212518],
#        [0.39823971, 0.22730459, 0.13654615, 0.10871873, 0.09239414,
#         0.08574256, 0.07833826, 0.06472861, 0.07641835, 0.06003824,
# ...

# %%
fig,ax=plt.subplots(figsize=(14,7))
my_colors = [(x/50.0, x/10.0, 0.15) for x in range(10)] 
for i,one in enumerate(result):
    one=one[:10]
    ax.plot(range(1,11,1),one,marker='*',label=i/10,c=my_colors[i],figure=fig,lw=2,ms=14)
#ax.xlim(1,5,1)

ax.set_xticks((range(1,11)))
ax.xaxis.set_tick_params(labelsize=27)
ax.yaxis.set_tick_params(labelsize=27)

plt.xlabel('Epoch',fontsize=25)
plt.ylabel('Loss',fontsize=25)
plt.legend(prop={'size': 20})
plt.xlim(1,10.3)

plt.savefig('loss_result1.pdf', bbox_inches = 'tight')

# %%
0.3292754943847656, 0.17797190856933592, 0.11269099349975586, 0.08920293426513672, 0.07412593612670898, 0.08049213485717774, 0.06649345321655273, 0.057378417587280274, 0.06472279243469238, 0.053580596923828126, 0.05007119979858399, 0.04964879379272461, 0.05051984062194824, 0.04576469306945801, 0.04809252758026123, 0.043004716873168945, 0.058048051452636716, 0.05575107383728027, 0.04372455673217773, 0.04090457096099853

# %%
fig,ax=plt.subplots(figsize=(14,7))
i_list=[0.6,0.7,0.8,0.9]
my_colors = [(x/5.0, x/10.0, 0.15) for x in range(5)] 
for i,one in enumerate(result[6:]):
    ax.plot(range(1,21,1),one,marker='*',label=i_list[i],c=my_colors[i],figure=fig)
#ax.xlim(1,5,1)

ax.set_xticks((range(1,21)))
ax.xaxis.set_tick_params(labelsize=27)
ax.yaxis.set_tick_params(labelsize=27)

